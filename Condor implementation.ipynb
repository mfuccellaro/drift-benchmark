# %% [markdown]
# ![Screenshot.jpg]

# %%
from IPython.display import Image
Image("Screenshot.jpg")

# %%
from sklearn.metrics

# %%
import pandas as pd
import numpy as np

# %%
r = RandomForestClassifier()

# %%
class condor:
    def __init__(self, model, step_size, X, y):
        model.fit(X, y)
        self.beta = [[1]]
        self.model_pool = [model]
        self.pred = pd.DataFrame()
        self.step_size = step_size

    def score(self, X):
        self.pred = pd.DataFrame()
        pred = pd.DataFrame()
        for i in range(len(self.model_pool)):
            model_pred_k = self.model_pool[i].predict(X)
            pred[i] = self.beta[i]*model_pred_k
            self.pred[i] = model_pred_k
        pred = pred.sum(1)/sum(self.beta)
    def update(self, y):
        for i in range(len(self.beta)):
            self.beta[i] = self.beta[i]*np.exp(-self.step_size*((self.pred-y)**2).sum()[0])

# %%
condor()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-d29dc2e2435d> in <module>
# ----> 1 condor()
#
# TypeError: __init__() missing 4 required positional arguments: 'model', 'step_size', 'X', and 'y'

# %%
y = pd.DataFrame([1,2,3,4])
yp = pd.DataFrame([4,2,55,4])

# %%
((y-yp)**2).sum()[0]
# Out:
# 2713

# %%
def condor(model, data, y=[], model_pool = []):
    if model_pool = []:
